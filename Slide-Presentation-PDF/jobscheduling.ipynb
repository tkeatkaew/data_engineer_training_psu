# %%
import schedule
import time as tm
from datetime import time, timedelta, datetime

def job():
    print("Hello")

schedule.every(5).seconds.do(job)
#schedule.every().seconds.do(job)
#schedule.every(2).minutes.do(job)
#schedule.every().day.at("17:14").do(job)
#schedule.every().day.at(":14").do(job)
#schedule.every().minute.at(":14").do(job)
#schedule.every().hour.until(time((11,33,42)).do(job)
#schedule.every().hour.until(timedelta(hours=8).do(job)
#schedule.every(1).to(5).seconds.do(job)
#
#j = schedule.every(1).to(5).seconds.do(job)
#counter = 0

while True:
    schedule.run_pending()
    tm.sleep(1)
    #counter +=1
    #if counter == 10:
        #schedule.cancel_job(j)
# Out:
# Hello
# Hello
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\PT\DE Training\Codes\jobscheduling.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/d%3A/PT/DE%20Training/Codes/jobscheduling.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a> while True:
#      <a href='vscode-notebook-cell:/d%3A/PT/DE%20Training/Codes/jobscheduling.ipynb#W0sZmlsZQ%3D%3D?line=21'>22</a>     schedule.run_pending()
# ---> <a href='vscode-notebook-cell:/d%3A/PT/DE%20Training/Codes/jobscheduling.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a>     tm.sleep(1)
#      <a href='vscode-notebook-cell:/d%3A/PT/DE%20Training/Codes/jobscheduling.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a>     #counter +=1
#      <a href='vscode-notebook-cell:/d%3A/PT/DE%20Training/Codes/jobscheduling.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a>     #if counter == 10:
#      <a href='vscode-notebook-cell:/d%3A/PT/DE%20Training/Codes/jobscheduling.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a>         #schedule.cancel_job(j)
#
# KeyboardInterrupt:
